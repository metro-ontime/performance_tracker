# %%
import json
from shapely.geometry import MultiPoint, LineString
from analyzer.track import create_ordered_line

track = json.load(open('data/shapefiles/bluejson.json'))

# %%
line = create_ordered_line(track)

# %%
line
