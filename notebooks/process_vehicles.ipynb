# %% [markdown]
# This script will process the vehicle positions in the raw data directory

# %%
import pandas as pd
import requests

scada = requests.get('http://api.metrocloudalliance.com/realtime/scada/')
data = scada.json()

df = pd.DataFrame(data)
df.head()
# Out:
#   ave_update_freq carrier direction heading last_report_ts  \
# 0              18      MT               180     1546147539
# 1              25      MT               180     1544621021
# 2             141      MT                 0     1545934311
# 3               0      MT               180     1545942201
# 4              65      MT                 0     1545953607
#
#            last_update last_update_ts        lat          lng pattern  \
# 0  2018-12-29 20:26:07     1546143967  34.022733   -118.33631
# 1  2018-12-12 04:23:57     1544617437  34.152505   -118.10424
# 2  2018-12-27 09:12:07     1545930727  33.768467  -118.193673
# 3  2018-12-27 11:23:38     1545938618  33.788038  -118.189355
# 4  2018-12-27 14:33:51     1545950031  33.836117   -118.20725
#
#   realtime_source_id realtime_source_type_id route             source  status  \
# 0                  3                       6        LACMTA Rail SCADA  online
# ...

# %%
df
# Out:
#     ave_update_freq carrier direction heading last_report_ts  \
# 0                18      MT               180     1546147539
# 1                25      MT               180     1544621021
# 2               141      MT                 0     1545934311
# 3                 0      MT               180     1545942201
# 4                65      MT                 0     1545953607
# 5                 2      MT               180     1546018157
# 6               121      MT                 0     1546153260
# 7                 0      MT               180     1544783670
# 8                24      MT                 0     1546153614
# 9                 0      MT                 0     1545314617
# 10              176      MT               180     1545960032
# 11              222      MT               180     1545979524
# 12              294      MT                 0     1545943275
# 13               35      MT               180     1546169101
# ...

# %%
from ..performance_tracker.analyzer.gtfs import load_and_parse_schedule
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-442306e97c9d> in <module>
# ----> 1 from ..performance_tracker.analyzer.gtfs import load_and_parse_schedule
#
# ValueError: attempted relative import beyond top-level package
